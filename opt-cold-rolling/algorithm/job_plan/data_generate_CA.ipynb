# %%
# 导入必要的库
import sys
import os

# 添加项目根目录到Python路径
sys.path.insert(0, os.path.abspath('../../'))

# 导入数据库相关模块
from table.TJCAUSP_ORIGIN import TJCAUSP_ORIGIN
from table.TJCAUSP import TJCAUSP
from table.TJCAUSP import TJCAUSP  # 导入新表的ORM
from sql.database import get_db_session, get_db
import pandas as pd

# %%
# 连接数据库并查询TJCAUSP_ORIGIN表的数据
with get_db_session() as db:
    records = db.query(TJCAUSP_ORIGIN).all()

    # 将查询结果转换为pandas DataFrame
    data = []
    for record in records:
        data.append({
            'id': record.id,
            'ORDER_NO': record.ORDER_NO,
            'ORDER_MONTH': record.ORDER_MONTH,
            'IN_MAT_MIN_WIDTH': record.IN_MAT_MIN_WIDTH,
            'IN_MAT_MAX_WIDTH': record.IN_MAT_MAX_WIDTH,
            'IN_MAT_MIN_THICK': record.IN_MAT_MIN_THICK,
            'IN_MAT_MAX_THICK': record.IN_MAT_MAX_THICK
        })

    df = pd.DataFrame(data)
    print(f"从TJCAUSP_ORIGIN表中查询到 {len(df)} 条记录")
# Out:
# 2025-10-22 12:57:15,951 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-10-22 12:57:15,953 INFO sqlalchemy.engine.Engine SELECT "TJCAUSP_ORIGIN".id AS "TJCAUSP_ORIGIN_id", "TJCAUSP_ORIGIN"."ORDER_NO" AS "TJCAUSP_ORIGIN_ORDER_NO", "TJCAUSP_ORIGIN"."ORDER_MONTH" AS "TJCAUSP_ORIGIN_ORDER_MONTH", "TJCAUSP_ORIGIN"."IN_MAT_MIN_WIDTH" AS "TJCAUSP_ORIGIN_IN_MAT_MIN_WIDTH", "TJCAUSP_ORIGIN"."IN_MAT_MAX_WIDTH" AS "TJCAUSP_ORIGIN_IN_MAT_MAX_WIDTH", "TJCAUSP_ORIGIN"."IN_MAT_MIN_THICK" AS "TJCAUSP_ORIGIN_IN_MAT_MIN_THICK", "TJCAUSP_ORIGIN"."IN_MAT_MAX_THICK" AS "TJCAUSP_ORIGIN_IN_MAT_MAX_THICK"
# FROM "TJCAUSP_ORIGIN"
# 2025-10-22 12:57:15,954 INFO sqlalchemy.engine.Engine [cached since 1129s ago] ()
# 从TJCAUSP_ORIGIN表中查询到 124 条记录
# 2025-10-22 12:57:15,958 INFO sqlalchemy.engine.Engine ROLLBACK

# %%
# 取df的前10条数据，根据每条数据的最大宽度、最小宽度、最大厚度、最小厚度，正太分布生成这个区间内的宽度和厚度，然后根据这个分布生成对应的数据，每条数据随机生成8到12条，然后把新得到的df打印出来
import numpy as np

# 取df的前10条数据
df_subset = df.head(15)

# 创建一个列表来存储新生成的数据
new_data = []

for index, row in df_subset.iterrows():
    # 获取当前行的宽度和厚度范围
    min_width = row['IN_MAT_MIN_WIDTH']
    max_width = row['IN_MAT_MAX_WIDTH']
    min_thick = row['IN_MAT_MIN_THICK']
    max_thick = row['IN_MAT_MAX_THICK']
    
    # 计算均值和标准差
    width_mean = (min_width + max_width) / 2
    width_std = (max_width - min_width) / 4  # 使用范围的1/4作为标准差，以确保大部分值在范围内
    thick_mean = (min_thick + max_thick) / 2
    thick_std = (max_thick - min_thick) / 4  # 使用范围的1/4作为标准差
    
    # 随机生成8到12条数据
    num_records = np.random.randint(5, 10)
    
    for _ in range(num_records):
        # 使用正态分布生成宽度和厚度
        width = np.random.normal(width_mean, width_std)
        # 确保生成的值在原始范围内
        width = max(min_width, min(max_width, width))
        
        thickness = np.random.normal(thick_mean, thick_std)
        # 确保生成的值在原始范围内
        thickness = max(min_thick, min(max_thick, thickness))
        
        # 创建新行，保留原始字段值，仅更新宽度和厚度
        new_row = {
            'id': row['id'],
            'ORDER_NO': row['ORDER_NO'],
            'ORDER_MONTH': row['ORDER_MONTH'],
            'IN_MAT_WIDTH': width,
            'IN_MAT_THICK': thickness
        }
        new_data.append(new_row)

# 将新生成的数据转换为DataFrame
new_df = pd.DataFrame(new_data)
print(f"新生成的数据行数：{len(new_df)}")
print(new_df)
# Out:
# 新生成的数据行数：106
#      id    ORDER_NO ORDER_MONTH  IN_MAT_WIDTH  IN_MAT_THICK
# 0     1  G025000870      202502    885.751638      2.038891
# 1     1  G025000870      202502    883.453724      2.113444
# 2     1  G025000870      202502    887.162539      2.098953
# 3     1  G025000870      202502    881.116535      2.021794
# 4     1  G025000870      202502    889.916988      2.026222
# ..   ..         ...         ...           ...           ...
# 101  15  G025001340      202502    962.464178      1.790940
# 102  15  G025001340      202502    962.473862      1.806119
# 103  15  G025001340      202502    963.295694      1.877106
# 104  15  G025001340      202502    961.607573      1.825830
# 105  15  G025001340      202502    963.695654      1.857122
#
# [106 rows x 5 columns]

# %%
# 将新生成的数据插入TJCAUSP表中
with get_db_session() as db:
    for _, row in new_df.iterrows():
        # 创建TJCAUSP对象并插入数据库
        new_record = TJCAUSP(
            ORDER_NO=row['ORDER_NO'],
            ORDER_MONTH=row['ORDER_MONTH'],
            IN_MAT_WIDTH=row['IN_MAT_WIDTH'],  # 使用生成的宽度值
            IN_MAT_THICK=row['IN_MAT_THICK']   # 使用生成的厚度值
        )
        db.add(new_record)

    # 提交事务以保存更改
    db.commit()

    print(f"成功将 {len(new_df)} 条记录插入TJCAUSP表中")
# Out:
# 2025-10-22 13:08:37,167 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-10-22 13:08:37,170 INFO sqlalchemy.engine.Engine INSERT INTO "TJCAUSP" ("ORDER_NO", "ORDER_MONTH", "IN_MAT_WIDTH", "IN_MAT_THICK") VALUES (?, ?, ?, ?) RETURNING id
# 2025-10-22 13:08:37,171 INFO sqlalchemy.engine.Engine [cached since 675.8s ago (insertmanyvalues) 1/106 (ordered; batch not supported)] ('G025000870', '202502', 885.7516376221471, 2.0388912421585315)
# 2025-10-22 13:08:37,174 INFO sqlalchemy.engine.Engine INSERT INTO "TJCAUSP" ("ORDER_NO", "ORDER_MONTH", "IN_MAT_WIDTH", "IN_MAT_THICK") VALUES (?, ?, ?, ?) RETURNING id
# 2025-10-22 13:08:37,175 INFO sqlalchemy.engine.Engine [insertmanyvalues 2/106 (ordered; batch not supported)] ('G025000870', '202502', 883.4537244260539, 2.113443714383332)
# 2025-10-22 13:08:37,175 INFO sqlalchemy.engine.Engine INSERT INTO "TJCAUSP" ("ORDER_NO", "ORDER_MONTH", "IN_MAT_WIDTH", "IN_MAT_THICK") VALUES (?, ?, ?, ?) RETURNING id
# 2025-10-22 13:08:37,176 INFO sqlalchemy.engine.Engine [insertmanyvalues 3/106 (ordered; batch not supported)] ('G025000870', '202502', 887.1625386837243, 2.0989533420578113)
# 2025-10-22 13:08:37,177 INFO sqlalchemy.engine.Engine INSERT INTO "TJCAUSP" ("ORDER_NO", "ORDER_MONTH", "IN_MAT_WIDTH", "IN_MAT_THICK") VALUES (?, ?, ?, ?) RETURNING id
# 2025-10-22 13:08:37,177 INFO sqlalchemy.engine.Engine [insertmanyvalues 4/106 (ordered; batch not supported)] ('G025000870', '202502', 881.1165353807468, 2.0217936694407816)
# 2025-10-22 13:08:37,177 INFO sqlalchemy.engine.Engine INSERT INTO "TJCAUSP" ("ORDER_NO", "ORDER_MONTH", "IN_MAT_WIDTH", "IN_MAT_THICK") VALUES (?, ?, ?, ?) RETURNING id
# 2025-10-22 13:08:37,178 INFO sqlalchemy.engine.Engine [insertmanyvalues 5/106 (ordered; batch not supported)] ('G025000870', '202502', 889.9169879636944, 2.026222048100365)
# 2025-10-22 13:08:37,178 INFO sqlalchemy.engine.Engine INSERT INTO "TJCAUSP" ("ORDER_NO", "ORDER_MONTH", "IN_MAT_WIDTH", "IN_MAT_THICK") VALUES (?, ?, ?, ?) RETURNING id
# 2025-10-22 13:08:37,179 INFO sqlalchemy.engine.Engine [insertmanyvalues 6/106 (ordered; batch not supported)] ('G025000870', '202502', 866.9408099610457, 0.213)
# 2025-10-22 13:08:37,179 INFO sqlalchemy.engine.Engine INSERT INTO "TJCAUSP" ("ORDER_NO", "ORDER_MONTH", "IN_MAT_WIDTH", "IN_MAT_THICK") VALUES (?, ?, ?, ?) RETURNING id
# 2025-10-22 13:08:37,180 INFO sqlalchemy.engine.Engine [insertmanyvalues 7/106 (ordered; batch not supported)] ('G025000870', '202502', 864.6943099953276, 0.21688997902357507)
# 2025-10-22 13:08:37,203 INFO sqlalchemy.engine.Engine INSERT INTO "TJCAUSP" ("ORDER_NO", "ORDER_MONTH", "IN_MAT_WIDTH", "IN_MAT_THICK") VALUES (?, ?, ?, ?) RETURNING id
# 2025-10-22 13:08:37,204 INFO sqlalchemy.engine.Engine [insertmanyvalues 8/106 (ordered; batch not supported)] ('G025000870', '202502', 865.7642422405556, 0.21797073636595155)
# 2025-10-22 13:08:37,205 INFO sqlalchemy.engine.Engine INSERT INTO "TJCAUSP" ("ORDER_NO", "ORDER_MONTH", "IN_MAT_WIDTH", "IN_MAT_THICK") VALUES (?, ?, ?, ?) RETURNING id
# 2025-10-22 13:08:37,205 INFO sqlalchemy.engine.Engine [insertmanyvalues 9/106 (ordered; batch not supported)] ('G025000870', '202502', 865.8294240082245, 0.21838453037614386)
# 2025-10-22 13:08:37,206 INFO sqlalchemy.engine.Engine INSERT INTO "TJCAUSP" ("ORDER_NO", "ORDER_MONTH", "IN_MAT_WIDTH", "IN_MAT_THICK") VALUES (?, ?, ?, ?) RETURNING id
# 2025-10-22 13:08:37,206 INFO sqlalchemy.engine.Engine [insertmanyvalues 10/106 (ordered; batch not supported)] ('G025000870', '202502', 865.5448149517476, 0.21668125628181265)
# 2025-10-22 13:08:37,207 INFO sqlalchemy.engine.Engine INSERT INTO "TJCAUSP" ("ORDER_NO", "ORDER_MONTH", "IN_MAT_WIDTH", "IN_MAT_THICK") VALUES (?, ?, ?, ?) RETURNING id
# 2025-10-22 13:08:37,207 INFO sqlalchemy.engine.Engine [insertmanyvalues 11/106 (ordered; batch not supported)] ('G025000870', '202502', 864.1277113655792, 0.213)
# 2025-10-22 13:08:37,208 INFO sqlalchemy.engine.Engine INSERT INTO "TJCAUSP" ("ORDER_NO", "ORDER_MONTH", "IN_MAT_WIDTH", "IN_MAT_THICK") VALUES (?, ?, ?, ?) RETURNING id
# 2025-10-22 13:08:37,209 INFO sqlalchemy.engine.Engine [insertmanyvalues 12/106 (ordered; batch not supported)] ('G025000870', '202502', 864.3713023410917, 0.2230740826931474)
# 2025-10-22 13:08:37,209 INFO sqlalchemy.engine.Engine INSERT INTO "TJCAUSP" ("ORDER_NO", "ORDER_MONTH", "IN_MAT_WIDTH", "IN_MAT_THICK") VALUES (?, ?, ?, ?) RETURNING id
# 2025-10-22 13:08:37,210 INFO sqlalchemy.engine.Engine [insertmanyvalues 13/106 (ordered; batch not supported)] ('G025000870', '202502', 863.4927198045245, 0.22245041322932335)
# 2025-10-22 13:08:37,211 INFO sqlalchemy.engine.Engine INSERT INTO "TJCAUSP" ("ORDER_NO", "ORDER_MONTH", "IN_MAT_WIDTH", "IN_MAT_THICK") VALUES (?, ?, ?, ?) RETURNING id
# 2025-10-22 13:08:37,211 INFO sqlalchemy.engine.Engine [insertmanyvalues 14/106 (ordered; batch not supported)] ('G025000870', '202502', 863.4626925592523, 0.21854984106955255)
# 2025-10-22 13:08:37,211 INFO sqlalchemy.engine.Engine INSERT INTO "TJCAUSP" ("ORDER_NO", "ORDER_MONTH", "IN_MAT_WIDTH", "IN_MAT_THICK") VALUES (?, ?, ?, ?) RETURNING id
# 2025-10-22 13:08:37,212 INFO sqlalchemy.engine.Engine [insertmanyvalues 15/106 (ordered; batch not supported)] ('G025000907', '202502', 893.276206473908, 1.7911688782473887)
# 2025-10-22 13:08:37,212 INFO sqlalchemy.engine.Engine INSERT INTO "TJCAUSP" ("ORDER_NO", "ORDER_MONTH", "IN_MAT_WIDTH", "IN_MAT_THICK") VALUES (?, ?, ?, ?) RETURNING id
# 2025-10-22 13:08:37,213 INFO sqlalchemy.engine.Engine [insertmanyvalues 16/106 (ordered; batch not supported)] ('G025000907', '202502', 893.7252133842977, 1.8014386003387557)
# 2025-10-22 13:08:37,213 INFO sqlalchemy.engine.Engine INSERT INTO "TJCAUSP" ("ORDER_NO", "ORDER_MONTH", "IN_MAT_WIDTH", "IN_MAT_THICK") VALUES (?, ?, ?, ?) RETURNING id
# 2025-10-22 13:08:37,213 INFO sqlalchemy.engine.Engine [insertmanyvalues 17/106 (ordered; batch not supported)] ('G025000907', '202502', 890.0037393828541, 1.7765577313435796)
# 2025-10-22 13:08:37,214 INFO sqlalchemy.engine.Engine INSERT INTO "TJCAUSP" ("ORDER_NO", "ORDER_MONTH", "IN_MAT_WIDTH", "IN_MAT_THICK") VALUES (?, ?, ?, ?) RETURNING id
# 2025-10-22 13:08:37,215 INFO sqlalchemy.engine.Engine [insertmanyvalues 18/106 (ordered; batch not supported)] ('G025000907', '202502', 899.4713597764722, 1.734751687168578)
# 2025-10-22 13:08:37,215 INFO sqlalchemy.engine.Engine INSERT INTO "TJCAUSP" ("ORDER_NO", "ORDER_MONTH", "IN_MAT_WIDTH", "IN_MAT_THICK") VALUES (?, ?, ?, ?) RETURNING id
# 2025-10-22 13:08:37,216 INFO sqlalchemy.engine.Engine [insertmanyvalues 19/106 (ordered; batch not supported)] ('G025000907', '202502', 893.5769847829868, 1.8297578249102608)
# 2025-10-22 13:08:37,217 INFO sqlalchemy.engine.Engine INSERT INTO "TJCAUSP" ("ORDER_NO", "ORDER_MONTH", "IN_MAT_WIDTH", "IN_MAT_THICK") VALUES (?, ?, ?, ?) RETURNING id
# 2025-10-22 13:08:37,217 INFO sqlalchemy.engine.Engine [insertmanyvalues 20/106 (ordered; batch not supported)] ('G025000907', '202502', 873.3466720378802, 0.18606297539429853)
# 2025-10-22 13:08:37,217 INFO sqlalchemy.engine.Engine INSERT INTO "TJCAUSP" ("ORDER_NO", "ORDER_MONTH", "IN_MAT_WIDTH", "IN_MAT_THICK") VALUES (?, ?, ?, ?) RETURNING id
# 2025-10-22 13:08:37,218 INFO sqlalchemy.engine.Engine [insertmanyvalues 21/106 (ordered; batch not supported)] ('G025000907', '202502', 873.9686386897417, 0.18532396083554645)
# 2025-10-22 13:08:37,218 INFO sqlalchemy.engine.Engine INSERT INTO "TJCAUSP" ("ORDER_NO", "ORDER_MONTH", "IN_MAT_WIDTH", "IN_MAT_THICK") VALUES (?, ?, ?, ?) RETURNING id
# 2025-10-22 13:08:37,219 INFO sqlalchemy.engine.Engine [insertmanyvalues 22/106 (ordered; batch not supported)] ('G025000907', '202502', 873.3379949513654, 0.18327629604248202)
# 2025-10-22 13:08:37,219 INFO sqlalchemy.engine.Engine INSERT INTO "TJCAUSP" ("ORDER_NO", "ORDER_MONTH", "IN_MAT_WIDTH", "IN_MAT_THICK") VALUES (?, ?, ?, ?) RETURNING id
# 2025-10-22 13:08:37,221 INFO sqlalchemy.engine.Engine [insertmanyvalues 23/106 (ordered; batch not supported)] ('G025000907', '202502', 871.7286845463082, 0.1863254742017006)
# 2025-10-22 13:08:37,222 INFO sqlalchemy.engine.Engine INSERT INTO "TJCAUSP" ("ORDER_NO", "ORDER_MONTH", "IN_MAT_WIDTH", "IN_MAT_THICK") VALUES (?, ?, ?, ?) RETURNING id
# 2025-10-22 13:08:37,222 INFO sqlalchemy.engine.Engine [insertmanyvalues 24/106 (ordered; batch not supported)] ('G025000907', '202502', 872.8845311670611, 0.18241089797955307)
# 2025-10-22 13:08:37,223 INFO sqlalchemy.engine.Engine INSERT INTO "TJCAUSP" ("ORDER_NO", "ORDER_MONTH", "IN_MAT_WIDTH", "IN_MAT_THICK") VALUES (?, ?, ?, ?) RETURNING id
# 2025-10-22 13:08:37,223 INFO sqlalchemy.engine.Engine [insertmanyvalues 25/106 (ordered; batch not supported)] ('G025000907', '202502', 871.7482188705872, 0.18440121804395315)
# 2025-10-22 13:08:37,223 INFO sqlalchemy.engine.Engine INSERT INTO "TJCAUSP" ("ORDER_NO", "ORDER_MONTH", "IN_MAT_WIDTH", "IN_MAT_THICK") VALUES (?, ?, ?, ?) RETURNING id
# 2025-10-22 13:08:37,224 INFO sqlalchemy.engine.Engine [insertmanyvalues 26/106 (ordered; batch not supported)] ('G025001099', '202502', 909.0005888638846, 0.21133421045961312)
# 2025-10-22 13:08:37,224 INFO sqlalchemy.engine.Engine INSERT INTO "TJCAUSP" ("ORDER_NO", "ORDER_MONTH", "IN_MAT_WIDTH", "IN_MAT_THICK") VALUES (?, ?, ?, ?) RETURNING id
# 2025-10-22 13:08:37,225 INFO sqlalchemy.engine.Engine [insertmanyvalues 27/106 (ordered; batch not supported)] ('G025001099', '202502', 908.6829090666544, 0.2076310991342134)
# 2025-10-22 13:08:37,226 INFO sqlalchemy.engine.Engine INSERT INTO "TJCAUSP" ("ORDER_NO", "ORDER_MONTH", "IN_MAT_WIDTH", "IN_MAT_THICK") VALUES (?, ?, ?, ?) RETURNING id
# 2025-10-22 13:08:37,226 INFO sqlalchemy.engine.Engine [insertmanyvalues 28/106 (ordered; batch not supported)] ('G025001099', '202502', 908.7976926237129, 0.21039182709651122)
# 2025-10-22 13:08:37,227 INFO sqlalchemy.engine.Engine INSERT INTO "TJCAUSP" ("ORDER_NO", "ORDER_MONTH", "IN_MAT_WIDTH", "IN_MAT_THICK") VALUES (?, ?, ?, ?) RETURNING id
# 2025-10-22 13:08:37,227 INFO sqlalchemy.engine.Engine [insertmanyvalues 29/106 (ordered; batch not supported)] ('G025001099', '202502', 908.6674412771121, 0.2045736276772694)
# 2025-10-22 13:08:37,228 INFO sqlalchemy.engine.Engine INSERT INTO "TJCAUSP" ("ORDER_NO", "ORDER_MONTH", "IN_MAT_WIDTH", "IN_MAT_THICK") VALUES (?, ?, ?, ?) RETURNING id
# 2025-10-22 13:08:37,229 INFO sqlalchemy.engine.Engine [insertmanyvalues 30/106 (ordered; batch not supported)] ('G025001099', '202502', 909.0030704732015, 0.20403837333942684)
# 2025-10-22 13:08:37,229 INFO sqlalchemy.engine.Engine INSERT INTO "TJCAUSP" ("ORDER_NO", "ORDER_MONTH", "IN_MAT_WIDTH", "IN_MAT_THICK") VALUES (?, ?, ?, ?) RETURNING id
# 2025-10-22 13:08:37,229 INFO sqlalchemy.engine.Engine [insertmanyvalues 31/106 (ordered; batch not supported)] ('G025001100', '202502', 929.9179832933294, 1.8419061712033684)
# 2025-10-22 13:08:37,231 INFO sqlalchemy.engine.Engine INSERT INTO "TJCAUSP" ("ORDER_NO", "ORDER_MONTH", "IN_MAT_WIDTH", "IN_MAT_THICK") VALUES (?, ?, ?, ?) RETURNING id
# 2025-10-22 13:08:37,231 INFO sqlalchemy.engine.Engine [insertmanyvalues 32/106 (ordered; batch not supported)] ('G025001100', '202502', 929.4952377853481, 1.8777458049531686)
# 2025-10-22 13:08:37,232 INFO sqlalchemy.engine.Engine INSERT INTO "TJCAUSP" ("ORDER_NO", "ORDER_MONTH", "IN_MAT_WIDTH", "IN_MAT_THICK") VALUES (?, ?, ?, ?) RETURNING id
# 2025-10-22 13:08:37,232 INFO sqlalchemy.engine.Engine [insertmanyvalues 33/106 (ordered; batch not supported)] ('G025001100', '202502', 933.8729449491442, 1.8015788301904674)
# 2025-10-22 13:08:37,233 INFO sqlalchemy.engine.Engine INSERT INTO "TJCAUSP" ("ORDER_NO", "ORDER_MONTH", "IN_MAT_WIDTH", "IN_MAT_THICK") VALUES (?, ?, ?, ?) RETURNING id
# 2025-10-22 13:08:37,234 INFO sqlalchemy.engine.Engine [insertmanyvalues 34/106 (ordered; batch not supported)] ('G025001100', '202502', 931.0669028972035, 1.7371384276830866)
# 2025-10-22 13:08:37,235 INFO sqlalchemy.engine.Engine INSERT INTO "TJCAUSP" ("ORDER_NO", "ORDER_MONTH", "IN_MAT_WIDTH", "IN_MAT_THICK") VALUES (?, ?, ?, ?) RETURNING id
# 2025-10-22 13:08:37,235 INFO sqlalchemy.engine.Engine [insertmanyvalues 35/106 (ordered; batch not supported)] ('G025001100', '202502', 936.1927787888596, 1.7376815007645765)
# 2025-10-22 13:08:37,236 INFO sqlalchemy.engine.Engine INSERT INTO "TJCAUSP" ("ORDER_NO", "ORDER_MONTH", "IN_MAT_WIDTH", "IN_MAT_THICK") VALUES (?, ?, ?, ?) RETURNING id
# 2025-10-22 13:08:37,237 INFO sqlalchemy.engine.Engine [insertmanyvalues 36/106 (ordered; batch not supported)] ('G025001100', '202502', 929.246679239419, 1.883568067297642)
# 2025-10-22 13:08:37,237 INFO sqlalchemy.engine.Engine INSERT INTO "TJCAUSP" ("ORDER_NO", "ORDER_MONTH", "IN_MAT_WIDTH", "IN_MAT_THICK") VALUES (?, ?, ?, ?) RETURNING id
# 2025-10-22 13:08:37,238 INFO sqlalchemy.engine.Engine [insertmanyvalues 37/106 (ordered; batch not supported)] ('G025000875', '202502', 1010.7412034577108, 2.0879236188338752)
# 2025-10-22 13:08:37,238 INFO sqlalchemy.engine.Engine INSERT INTO "TJCAUSP" ("ORDER_NO", "ORDER_MONTH", "IN_MAT_WIDTH", "IN_MAT_THICK") VALUES (?, ?, ?, ?) RETURNING id
# 2025-10-22 13:08:37,239 INFO sqlalchemy.engine.Engine [insertmanyvalues 38/106 (ordered; batch not supported)] ('G025000875', '202502', 1006.5788224813081, 2.1392016822253286)
# 2025-10-22 13:08:37,239 INFO sqlalchemy.engine.Engine INSERT INTO "TJCAUSP" ("ORDER_NO", "ORDER_MONTH", "IN_MAT_WIDTH", "IN_MAT_THICK") VALUES (?, ?, ?, ?) RETURNING id
# 2025-10-22 13:08:37,240 INFO sqlalchemy.engine.Engine [insertmanyvalues 39/106 (ordered; batch not supported)] ('G025000875', '202502', 1012.0, 2.131247165101374)
# 2025-10-22 13:08:37,240 INFO sqlalchemy.engine.Engine INSERT INTO "TJCAUSP" ("ORDER_NO", "ORDER_MONTH", "IN_MAT_WIDTH", "IN_MAT_THICK") VALUES (?, ?, ?, ?) RETURNING id
# 2025-10-22 13:08:37,240 INFO sqlalchemy.engine.Engine [insertmanyvalues 40/106 (ordered; batch not supported)] ('G025000875', '202502', 1007.4042835737085, 2.1825342918001756)
# 2025-10-22 13:08:37,242 INFO sqlalchemy.engine.Engine INSERT INTO "TJCAUSP" ("ORDER_NO", "ORDER_MONTH", "IN_MAT_WIDTH", "IN_MAT_THICK") VALUES (?, ?, ?, ?) RETURNING id
# 2025-10-22 13:08:37,242 INFO sqlalchemy.engine.Engine [insertmanyvalues 41/106 (ordered; batch not supported)] ('G025000875', '202502', 1006.9122139356801, 2.162022695248395)
# 2025-10-22 13:08:37,242 INFO sqlalchemy.engine.Engine INSERT INTO "TJCAUSP" ("ORDER_NO", "ORDER_MONTH", "IN_MAT_WIDTH", "IN_MAT_THICK") VALUES (?, ?, ?, ?) RETURNING id
# 2025-10-22 13:08:37,243 INFO sqlalchemy.engine.Engine [insertmanyvalues 42/106 (ordered; batch not supported)] ('G025000875', '202502', 1005.4755382786553, 2.0785177529157344)
# 2025-10-22 13:08:37,244 INFO sqlalchemy.engine.Engine INSERT INTO "TJCAUSP" ("ORDER_NO", "ORDER_MONTH", "IN_MAT_WIDTH", "IN_MAT_THICK") VALUES (?, ?, ?, ?) RETURNING id
# 2025-10-22 13:08:37,244 INFO sqlalchemy.engine.Engine [insertmanyvalues 43/106 (ordered; batch not supported)] ('G025000875', '202502', 1001.682154913955, 2.1047662582470035)
# 2025-10-22 13:08:37,245 INFO sqlalchemy.engine.Engine INSERT INTO "TJCAUSP" ("ORDER_NO", "ORDER_MONTH", "IN_MAT_WIDTH", "IN_MAT_THICK") VALUES (?, ?, ?, ?) RETURNING id
# 2025-10-22 13:08:37,245 INFO sqlalchemy.engine.Engine [insertmanyvalues 44/106 (ordered; batch not supported)] ('G025000875', '202502', 1004.1611181964223, 2.1071759156509193)
# 2025-10-22 13:08:37,245 INFO sqlalchemy.engine.Engine INSERT INTO "TJCAUSP" ("ORDER_NO", "ORDER_MONTH", "IN_MAT_WIDTH", "IN_MAT_THICK") VALUES (?, ?, ?, ?) RETURNING id
# 2025-10-22 13:08:37,246 INFO sqlalchemy.engine.Engine [insertmanyvalues 45/106 (ordered; batch not supported)] ('G025000875', '202502', 985.2664946080873, 0.24597956367401833)
# 2025-10-22 13:08:37,246 INFO sqlalchemy.engine.Engine INSERT INTO "TJCAUSP" ("ORDER_NO", "ORDER_MONTH", "IN_MAT_WIDTH", "IN_MAT_THICK") VALUES (?, ?, ?, ?) RETURNING id
# 2025-10-22 13:08:37,246 INFO sqlalchemy.engine.Engine [insertmanyvalues 46/106 (ordered; batch not supported)] ('G025000875', '202502', 982.0187970688465, 0.25068398156316196)
# 2025-10-22 13:08:37,247 INFO sqlalchemy.engine.Engine INSERT INTO "TJCAUSP" ("ORDER_NO", "ORDER_MONTH", "IN_MAT_WIDTH", "IN_MAT_THICK") VALUES (?, ?, ?, ?) RETURNING id
# 2025-10-22 13:08:37,247 INFO sqlalchemy.engine.Engine [insertmanyvalues 47/106 (ordered; batch not supported)] ('G025000875', '202502', 985.0434944008957, 0.2451778143670724)
# 2025-10-22 13:08:37,248 INFO sqlalchemy.engine.Engine INSERT INTO "TJCAUSP" ("ORDER_NO", "ORDER_MONTH", "IN_MAT_WIDTH", "IN_MAT_THICK") VALUES (?, ?, ?, ?) RETURNING id
# 2025-10-22 13:08:37,249 INFO sqlalchemy.engine.Engine [insertmanyvalues 48/106 (ordered; batch not supported)] ('G025000875', '202502', 982.1963106451359, 0.2526320995297111)
# 2025-10-22 13:08:37,251 INFO sqlalchemy.engine.Engine INSERT INTO "TJCAUSP" ("ORDER_NO", "ORDER_MONTH", "IN_MAT_WIDTH", "IN_MAT_THICK") VALUES (?, ?, ?, ?) RETURNING id
# 2025-10-22 13:08:37,251 INFO sqlalchemy.engine.Engine [insertmanyvalues 49/106 (ordered; batch not supported)] ('G025000875', '202502', 983.0462861514835, 0.237)
# 2025-10-22 13:08:37,252 INFO sqlalchemy.engine.Engine INSERT INTO "TJCAUSP" ("ORDER_NO", "ORDER_MONTH", "IN_MAT_WIDTH", "IN_MAT_THICK") VALUES (?, ?, ?, ?) RETURNING id
# 2025-10-22 13:08:37,252 INFO sqlalchemy.engine.Engine [insertmanyvalues 50/106 (ordered; batch not supported)] ('G025000875', '202502', 983.5595164454911, 0.24459575073697148)
# 2025-10-22 13:08:37,253 INFO sqlalchemy.engine.Engine INSERT INTO "TJCAUSP" ("ORDER_NO", "ORDER_MONTH", "IN_MAT_WIDTH", "IN_MAT_THICK") VALUES (?, ?, ?, ?) RETURNING id
# 2025-10-22 13:08:37,254 INFO sqlalchemy.engine.Engine [insertmanyvalues 51/106 (ordered; batch not supported)] ('G025001244', '202502', 873.8254752387223, 2.0349669960437753)
# 2025-10-22 13:08:37,255 INFO sqlalchemy.engine.Engine INSERT INTO "TJCAUSP" ("ORDER_NO", "ORDER_MONTH", "IN_MAT_WIDTH", "IN_MAT_THICK") VALUES (?, ?, ?, ?) RETURNING id
# 2025-10-22 13:08:37,255 INFO sqlalchemy.engine.Engine [insertmanyvalues 52/106 (ordered; batch not supported)] ('G025001244', '202502', 879.3932062610369, 1.8931846247637116)
# 2025-10-22 13:08:37,256 INFO sqlalchemy.engine.Engine INSERT INTO "TJCAUSP" ("ORDER_NO", "ORDER_MONTH", "IN_MAT_WIDTH", "IN_MAT_THICK") VALUES (?, ?, ?, ?) RETURNING id
# 2025-10-22 13:08:37,257 INFO sqlalchemy.engine.Engine [insertmanyvalues 53/106 (ordered; batch not supported)] ('G025001244', '202502', 878.9714207777592, 1.9916632396304979)
# 2025-10-22 13:08:37,257 INFO sqlalchemy.engine.Engine INSERT INTO "TJCAUSP" ("ORDER_NO", "ORDER_MONTH", "IN_MAT_WIDTH", "IN_MAT_THICK") VALUES (?, ?, ?, ?) RETURNING id
# 2025-10-22 13:08:37,258 INFO sqlalchemy.engine.Engine [insertmanyvalues 54/106 (ordered; batch not supported)] ('G025001244', '202502', 884.639247974668, 2.0217445609218143)
# 2025-10-22 13:08:37,259 INFO sqlalchemy.engine.Engine INSERT INTO "TJCAUSP" ("ORDER_NO", "ORDER_MONTH", "IN_MAT_WIDTH", "IN_MAT_THICK") VALUES (?, ?, ?, ?) RETURNING id
# 2025-10-22 13:08:37,259 INFO sqlalchemy.engine.Engine [insertmanyvalues 55/106 (ordered; batch not supported)] ('G025001244', '202502', 880.3595313556065, 2.085876551785802)
# 2025-10-22 13:08:37,260 INFO sqlalchemy.engine.Engine INSERT INTO "TJCAUSP" ("ORDER_NO", "ORDER_MONTH", "IN_MAT_WIDTH", "IN_MAT_THICK") VALUES (?, ?, ?, ?) RETURNING id
# 2025-10-22 13:08:37,261 INFO sqlalchemy.engine.Engine [insertmanyvalues 56/106 (ordered; batch not supported)] ('G025001244', '202502', 873.1455732791329, 2.0718295520753003)
# 2025-10-22 13:08:37,261 INFO sqlalchemy.engine.Engine INSERT INTO "TJCAUSP" ("ORDER_NO", "ORDER_MONTH", "IN_MAT_WIDTH", "IN_MAT_THICK") VALUES (?, ?, ?, ?) RETURNING id
# 2025-10-22 13:08:37,262 INFO sqlalchemy.engine.Engine [insertmanyvalues 57/106 (ordered; batch not supported)] ('G025001244', '202502', 879.5961207995502, 2.13)
# 2025-10-22 13:08:37,262 INFO sqlalchemy.engine.Engine INSERT INTO "TJCAUSP" ("ORDER_NO", "ORDER_MONTH", "IN_MAT_WIDTH", "IN_MAT_THICK") VALUES (?, ?, ?, ?) RETURNING id
# 2025-10-22 13:08:37,264 INFO sqlalchemy.engine.Engine [insertmanyvalues 58/106 (ordered; batch not supported)] ('G025001244', '202502', 880.9547939247748, 2.07139577984169)
# 2025-10-22 13:08:37,264 INFO sqlalchemy.engine.Engine INSERT INTO "TJCAUSP" ("ORDER_NO", "ORDER_MONTH", "IN_MAT_WIDTH", "IN_MAT_THICK") VALUES (?, ?, ?, ?) RETURNING id
# 2025-10-22 13:08:37,265 INFO sqlalchemy.engine.Engine [insertmanyvalues 59/106 (ordered; batch not supported)] ('G025001244', '202502', 882.1492179291529, 2.014803624529827)
# 2025-10-22 13:08:37,265 INFO sqlalchemy.engine.Engine INSERT INTO "TJCAUSP" ("ORDER_NO", "ORDER_MONTH", "IN_MAT_WIDTH", "IN_MAT_THICK") VALUES (?, ?, ?, ?) RETURNING id
# 2025-10-22 13:08:37,266 INFO sqlalchemy.engine.Engine [insertmanyvalues 60/106 (ordered; batch not supported)] ('G025001244', '202502', 856.3971664616054, 0.17984342004116938)
# 2025-10-22 13:08:37,267 INFO sqlalchemy.engine.Engine INSERT INTO "TJCAUSP" ("ORDER_NO", "ORDER_MONTH", "IN_MAT_WIDTH", "IN_MAT_THICK") VALUES (?, ?, ?, ?) RETURNING id
# 2025-10-22 13:08:37,267 INFO sqlalchemy.engine.Engine [insertmanyvalues 61/106 (ordered; batch not supported)] ('G025001244', '202502', 856.8536334842619, 0.18235399151663462)
# 2025-10-22 13:08:37,268 INFO sqlalchemy.engine.Engine INSERT INTO "TJCAUSP" ("ORDER_NO", "ORDER_MONTH", "IN_MAT_WIDTH", "IN_MAT_THICK") VALUES (?, ?, ?, ?) RETURNING id
# 2025-10-22 13:08:37,269 INFO sqlalchemy.engine.Engine [insertmanyvalues 62/106 (ordered; batch not supported)] ('G025001244', '202502', 857.5912321225786, 0.1818228848383239)
# 2025-10-22 13:08:37,269 INFO sqlalchemy.engine.Engine INSERT INTO "TJCAUSP" ("ORDER_NO", "ORDER_MONTH", "IN_MAT_WIDTH", "IN_MAT_THICK") VALUES (?, ?, ?, ?) RETURNING id
# 2025-10-22 13:08:37,270 INFO sqlalchemy.engine.Engine [insertmanyvalues 63/106 (ordered; batch not supported)] ('G025001244', '202502', 857.6146194203611, 0.187)
# 2025-10-22 13:08:37,271 INFO sqlalchemy.engine.Engine INSERT INTO "TJCAUSP" ("ORDER_NO", "ORDER_MONTH", "IN_MAT_WIDTH", "IN_MAT_THICK") VALUES (?, ?, ?, ?) RETURNING id
# 2025-10-22 13:08:37,272 INFO sqlalchemy.engine.Engine [insertmanyvalues 64/106 (ordered; batch not supported)] ('G025001244', '202502', 857.5390402012096, 0.18261805630613615)
# 2025-10-22 13:08:37,272 INFO sqlalchemy.engine.Engine INSERT INTO "TJCAUSP" ("ORDER_NO", "ORDER_MONTH", "IN_MAT_WIDTH", "IN_MAT_THICK") VALUES (?, ?, ?, ?) RETURNING id
# 2025-10-22 13:08:37,272 INFO sqlalchemy.engine.Engine [insertmanyvalues 65/106 (ordered; batch not supported)] ('G025001244', '202502', 855.091425689239, 0.18265459276706644)
# 2025-10-22 13:08:37,273 INFO sqlalchemy.engine.Engine INSERT INTO "TJCAUSP" ("ORDER_NO", "ORDER_MONTH", "IN_MAT_WIDTH", "IN_MAT_THICK") VALUES (?, ?, ?, ?) RETURNING id
# 2025-10-22 13:08:37,273 INFO sqlalchemy.engine.Engine [insertmanyvalues 66/106 (ordered; batch not supported)] ('G025001244', '202502', 856.4520525153864, 0.1835097938176847)
# 2025-10-22 13:08:37,274 INFO sqlalchemy.engine.Engine INSERT INTO "TJCAUSP" ("ORDER_NO", "ORDER_MONTH", "IN_MAT_WIDTH", "IN_MAT_THICK") VALUES (?, ?, ?, ?) RETURNING id
# 2025-10-22 13:08:37,275 INFO sqlalchemy.engine.Engine [insertmanyvalues 67/106 (ordered; batch not supported)] ('G025001325', '202502', 814.7342749399094, 2.06)
# 2025-10-22 13:08:37,275 INFO sqlalchemy.engine.Engine INSERT INTO "TJCAUSP" ("ORDER_NO", "ORDER_MONTH", "IN_MAT_WIDTH", "IN_MAT_THICK") VALUES (?, ?, ?, ?) RETURNING id
# 2025-10-22 13:08:37,276 INFO sqlalchemy.engine.Engine [insertmanyvalues 68/106 (ordered; batch not supported)] ('G025001325', '202502', 819.0, 2.182532545972459)
# 2025-10-22 13:08:37,276 INFO sqlalchemy.engine.Engine INSERT INTO "TJCAUSP" ("ORDER_NO", "ORDER_MONTH", "IN_MAT_WIDTH", "IN_MAT_THICK") VALUES (?, ?, ?, ?) RETURNING id
# 2025-10-22 13:08:37,277 INFO sqlalchemy.engine.Engine [insertmanyvalues 69/106 (ordered; batch not supported)] ('G025001325', '202502', 816.5814921865842, 2.06)
# 2025-10-22 13:08:37,278 INFO sqlalchemy.engine.Engine INSERT INTO "TJCAUSP" ("ORDER_NO", "ORDER_MONTH", "IN_MAT_WIDTH", "IN_MAT_THICK") VALUES (?, ?, ?, ?) RETURNING id
# 2025-10-22 13:08:37,278 INFO sqlalchemy.engine.Engine [insertmanyvalues 70/106 (ordered; batch not supported)] ('G025001325', '202502', 809.685347841505, 2.191781940891924)
# 2025-10-22 13:08:37,279 INFO sqlalchemy.engine.Engine INSERT INTO "TJCAUSP" ("ORDER_NO", "ORDER_MONTH", "IN_MAT_WIDTH", "IN_MAT_THICK") VALUES (?, ?, ?, ?) RETURNING id
# 2025-10-22 13:08:37,280 INFO sqlalchemy.engine.Engine [insertmanyvalues 71/106 (ordered; batch not supported)] ('G025001325', '202502', 812.5923413219407, 2.1614824837497553)
# 2025-10-22 13:08:37,280 INFO sqlalchemy.engine.Engine INSERT INTO "TJCAUSP" ("ORDER_NO", "ORDER_MONTH", "IN_MAT_WIDTH", "IN_MAT_THICK") VALUES (?, ?, ?, ?) RETURNING id
# 2025-10-22 13:08:37,282 INFO sqlalchemy.engine.Engine [insertmanyvalues 72/106 (ordered; batch not supported)] ('G025001325', '202502', 811.9571118985751, 2.216315364924574)
# 2025-10-22 13:08:37,282 INFO sqlalchemy.engine.Engine INSERT INTO "TJCAUSP" ("ORDER_NO", "ORDER_MONTH", "IN_MAT_WIDTH", "IN_MAT_THICK") VALUES (?, ?, ?, ?) RETURNING id
# 2025-10-22 13:08:37,283 INFO sqlalchemy.engine.Engine [insertmanyvalues 73/106 (ordered; batch not supported)] ('G025001325', '202502', 809.7305050229378, 2.0992297017843695)
# 2025-10-22 13:08:37,284 INFO sqlalchemy.engine.Engine INSERT INTO "TJCAUSP" ("ORDER_NO", "ORDER_MONTH", "IN_MAT_WIDTH", "IN_MAT_THICK") VALUES (?, ?, ?, ?) RETURNING id
# 2025-10-22 13:08:37,284 INFO sqlalchemy.engine.Engine [insertmanyvalues 74/106 (ordered; batch not supported)] ('G025001325', '202502', 819.0, 2.14424343459444)
# 2025-10-22 13:08:37,285 INFO sqlalchemy.engine.Engine INSERT INTO "TJCAUSP" ("ORDER_NO", "ORDER_MONTH", "IN_MAT_WIDTH", "IN_MAT_THICK") VALUES (?, ?, ?, ?) RETURNING id
# 2025-10-22 13:08:37,286 INFO sqlalchemy.engine.Engine [insertmanyvalues 75/106 (ordered; batch not supported)] ('G025001325', '202502', 789.4818896344062, 0.22160241954814786)
# 2025-10-22 13:08:37,286 INFO sqlalchemy.engine.Engine INSERT INTO "TJCAUSP" ("ORDER_NO", "ORDER_MONTH", "IN_MAT_WIDTH", "IN_MAT_THICK") VALUES (?, ?, ?, ?) RETURNING id
# 2025-10-22 13:08:37,287 INFO sqlalchemy.engine.Engine [insertmanyvalues 76/106 (ordered; batch not supported)] ('G025001325', '202502', 790.8298443544961, 0.21746549089849718)
# 2025-10-22 13:08:37,287 INFO sqlalchemy.engine.Engine INSERT INTO "TJCAUSP" ("ORDER_NO", "ORDER_MONTH", "IN_MAT_WIDTH", "IN_MAT_THICK") VALUES (?, ?, ?, ?) RETURNING id
# 2025-10-22 13:08:37,288 INFO sqlalchemy.engine.Engine [insertmanyvalues 77/106 (ordered; batch not supported)] ('G025001325', '202502', 789.7883964175523, 0.2231322194832053)
# 2025-10-22 13:08:37,288 INFO sqlalchemy.engine.Engine INSERT INTO "TJCAUSP" ("ORDER_NO", "ORDER_MONTH", "IN_MAT_WIDTH", "IN_MAT_THICK") VALUES (?, ?, ?, ?) RETURNING id
# 2025-10-22 13:08:37,289 INFO sqlalchemy.engine.Engine [insertmanyvalues 78/106 (ordered; batch not supported)] ('G025001325', '202502', 790.8611428522312, 0.21788364578514458)
# 2025-10-22 13:08:37,289 INFO sqlalchemy.engine.Engine INSERT INTO "TJCAUSP" ("ORDER_NO", "ORDER_MONTH", "IN_MAT_WIDTH", "IN_MAT_THICK") VALUES (?, ?, ?, ?) RETURNING id
# 2025-10-22 13:08:37,291 INFO sqlalchemy.engine.Engine [insertmanyvalues 79/106 (ordered; batch not supported)] ('G025001325', '202502', 788.8988039282202, 0.21884488021350554)
# 2025-10-22 13:08:37,292 INFO sqlalchemy.engine.Engine INSERT INTO "TJCAUSP" ("ORDER_NO", "ORDER_MONTH", "IN_MAT_WIDTH", "IN_MAT_THICK") VALUES (?, ?, ?, ?) RETURNING id
# 2025-10-22 13:08:37,292 INFO sqlalchemy.engine.Engine [insertmanyvalues 80/106 (ordered; batch not supported)] ('G025001325', '202502', 788.833693983729, 0.216)
# 2025-10-22 13:08:37,293 INFO sqlalchemy.engine.Engine INSERT INTO "TJCAUSP" ("ORDER_NO", "ORDER_MONTH", "IN_MAT_WIDTH", "IN_MAT_THICK") VALUES (?, ?, ?, ?) RETURNING id
# 2025-10-22 13:08:37,293 INFO sqlalchemy.engine.Engine [insertmanyvalues 81/106 (ordered; batch not supported)] ('G025001325', '202502', 791.1993421889696, 0.21726906782929623)
# 2025-10-22 13:08:37,293 INFO sqlalchemy.engine.Engine INSERT INTO "TJCAUSP" ("ORDER_NO", "ORDER_MONTH", "IN_MAT_WIDTH", "IN_MAT_THICK") VALUES (?, ?, ?, ?) RETURNING id
# 2025-10-22 13:08:37,294 INFO sqlalchemy.engine.Engine [insertmanyvalues 82/106 (ordered; batch not supported)] ('G025001326', '202502', 802.918341830332, 2.17013319236927)
# 2025-10-22 13:08:37,295 INFO sqlalchemy.engine.Engine INSERT INTO "TJCAUSP" ("ORDER_NO", "ORDER_MONTH", "IN_MAT_WIDTH", "IN_MAT_THICK") VALUES (?, ?, ?, ?) RETURNING id
# 2025-10-22 13:08:37,296 INFO sqlalchemy.engine.Engine [insertmanyvalues 83/106 (ordered; batch not supported)] ('G025001326', '202502', 796.8551069845826, 2.166077065968316)
# 2025-10-22 13:08:37,297 INFO sqlalchemy.engine.Engine INSERT INTO "TJCAUSP" ("ORDER_NO", "ORDER_MONTH", "IN_MAT_WIDTH", "IN_MAT_THICK") VALUES (?, ?, ?, ?) RETURNING id
# 2025-10-22 13:08:37,297 INFO sqlalchemy.engine.Engine [insertmanyvalues 84/106 (ordered; batch not supported)] ('G025001326', '202502', 801.9882742413465, 2.221744559361922)
# 2025-10-22 13:08:37,298 INFO sqlalchemy.engine.Engine INSERT INTO "TJCAUSP" ("ORDER_NO", "ORDER_MONTH", "IN_MAT_WIDTH", "IN_MAT_THICK") VALUES (?, ?, ?, ?) RETURNING id
# 2025-10-22 13:08:37,299 INFO sqlalchemy.engine.Engine [insertmanyvalues 85/106 (ordered; batch not supported)] ('G025001326', '202502', 799.4034347234024, 2.1573489225400606)
# 2025-10-22 13:08:37,300 INFO sqlalchemy.engine.Engine INSERT INTO "TJCAUSP" ("ORDER_NO", "ORDER_MONTH", "IN_MAT_WIDTH", "IN_MAT_THICK") VALUES (?, ?, ?, ?) RETURNING id
# 2025-10-22 13:08:37,300 INFO sqlalchemy.engine.Engine [insertmanyvalues 86/106 (ordered; batch not supported)] ('G025001326', '202502', 794.1725256265811, 2.2369218856153408)
# 2025-10-22 13:08:37,301 INFO sqlalchemy.engine.Engine INSERT INTO "TJCAUSP" ("ORDER_NO", "ORDER_MONTH", "IN_MAT_WIDTH", "IN_MAT_THICK") VALUES (?, ?, ?, ?) RETURNING id
# 2025-10-22 13:08:37,301 INFO sqlalchemy.engine.Engine [insertmanyvalues 87/106 (ordered; batch not supported)] ('G025001326', '202502', 801.2124170668312, 2.06)
# 2025-10-22 13:08:37,302 INFO sqlalchemy.engine.Engine INSERT INTO "TJCAUSP" ("ORDER_NO", "ORDER_MONTH", "IN_MAT_WIDTH", "IN_MAT_THICK") VALUES (?, ?, ?, ?) RETURNING id
# 2025-10-22 13:08:37,302 INFO sqlalchemy.engine.Engine [insertmanyvalues 88/106 (ordered; batch not supported)] ('G025001326', '202502', 801.391328943359, 2.2318588880419665)
# 2025-10-22 13:08:37,303 INFO sqlalchemy.engine.Engine INSERT INTO "TJCAUSP" ("ORDER_NO", "ORDER_MONTH", "IN_MAT_WIDTH", "IN_MAT_THICK") VALUES (?, ?, ?, ?) RETURNING id
# 2025-10-22 13:08:37,304 INFO sqlalchemy.engine.Engine [insertmanyvalues 89/106 (ordered; batch not supported)] ('G025001326', '202502', 778.6520983287077, 0.23330182018428758)
# 2025-10-22 13:08:37,304 INFO sqlalchemy.engine.Engine INSERT INTO "TJCAUSP" ("ORDER_NO", "ORDER_MONTH", "IN_MAT_WIDTH", "IN_MAT_THICK") VALUES (?, ?, ?, ?) RETURNING id
# 2025-10-22 13:08:37,305 INFO sqlalchemy.engine.Engine [insertmanyvalues 90/106 (ordered; batch not supported)] ('G025001326', '202502', 777.8092959138409, 0.23205524736322788)
# 2025-10-22 13:08:37,305 INFO sqlalchemy.engine.Engine INSERT INTO "TJCAUSP" ("ORDER_NO", "ORDER_MONTH", "IN_MAT_WIDTH", "IN_MAT_THICK") VALUES (?, ?, ?, ?) RETURNING id
# 2025-10-22 13:08:37,306 INFO sqlalchemy.engine.Engine [insertmanyvalues 91/106 (ordered; batch not supported)] ('G025001326', '202502', 778.7269813167643, 0.23188806392452185)
# 2025-10-22 13:08:37,307 INFO sqlalchemy.engine.Engine INSERT INTO "TJCAUSP" ("ORDER_NO", "ORDER_MONTH", "IN_MAT_WIDTH", "IN_MAT_THICK") VALUES (?, ?, ?, ?) RETURNING id
# 2025-10-22 13:08:37,308 INFO sqlalchemy.engine.Engine [insertmanyvalues 92/106 (ordered; batch not supported)] ('G025001326', '202502', 779.5758634870112, 0.2378316536841844)
# 2025-10-22 13:08:37,308 INFO sqlalchemy.engine.Engine INSERT INTO "TJCAUSP" ("ORDER_NO", "ORDER_MONTH", "IN_MAT_WIDTH", "IN_MAT_THICK") VALUES (?, ?, ?, ?) RETURNING id
# 2025-10-22 13:08:37,309 INFO sqlalchemy.engine.Engine [insertmanyvalues 93/106 (ordered; batch not supported)] ('G025001326', '202502', 778.7638440396918, 0.2294587715069054)
# 2025-10-22 13:08:37,309 INFO sqlalchemy.engine.Engine INSERT INTO "TJCAUSP" ("ORDER_NO", "ORDER_MONTH", "IN_MAT_WIDTH", "IN_MAT_THICK") VALUES (?, ?, ?, ?) RETURNING id
# 2025-10-22 13:08:37,311 INFO sqlalchemy.engine.Engine [insertmanyvalues 94/106 (ordered; batch not supported)] ('G025001326', '202502', 782.0, 0.231371527026231)
# 2025-10-22 13:08:37,312 INFO sqlalchemy.engine.Engine INSERT INTO "TJCAUSP" ("ORDER_NO", "ORDER_MONTH", "IN_MAT_WIDTH", "IN_MAT_THICK") VALUES (?, ?, ?, ?) RETURNING id
# 2025-10-22 13:08:37,312 INFO sqlalchemy.engine.Engine [insertmanyvalues 95/106 (ordered; batch not supported)] ('G025001326', '202502', 782.0, 0.2292416902637148)
# 2025-10-22 13:08:37,313 INFO sqlalchemy.engine.Engine INSERT INTO "TJCAUSP" ("ORDER_NO", "ORDER_MONTH", "IN_MAT_WIDTH", "IN_MAT_THICK") VALUES (?, ?, ?, ?) RETURNING id
# 2025-10-22 13:08:37,313 INFO sqlalchemy.engine.Engine [insertmanyvalues 96/106 (ordered; batch not supported)] ('G025001326', '202502', 777.6341009295278, 0.23821027200954828)
# 2025-10-22 13:08:37,314 INFO sqlalchemy.engine.Engine INSERT INTO "TJCAUSP" ("ORDER_NO", "ORDER_MONTH", "IN_MAT_WIDTH", "IN_MAT_THICK") VALUES (?, ?, ?, ?) RETURNING id
# 2025-10-22 13:08:37,315 INFO sqlalchemy.engine.Engine [insertmanyvalues 97/106 (ordered; batch not supported)] ('G025001326', '202502', 777.7711037864661, 0.23518316475520157)
# 2025-10-22 13:08:37,315 INFO sqlalchemy.engine.Engine INSERT INTO "TJCAUSP" ("ORDER_NO", "ORDER_MONTH", "IN_MAT_WIDTH", "IN_MAT_THICK") VALUES (?, ?, ?, ?) RETURNING id
# 2025-10-22 13:08:37,316 INFO sqlalchemy.engine.Engine [insertmanyvalues 98/106 (ordered; batch not supported)] ('G025001340', '202502', 966.4379244564971, 1.8141229337756044)
# 2025-10-22 13:08:37,317 INFO sqlalchemy.engine.Engine INSERT INTO "TJCAUSP" ("ORDER_NO", "ORDER_MONTH", "IN_MAT_WIDTH", "IN_MAT_THICK") VALUES (?, ?, ?, ?) RETURNING id
# 2025-10-22 13:08:37,317 INFO sqlalchemy.engine.Engine [insertmanyvalues 99/106 (ordered; batch not supported)] ('G025001340', '202502', 968.6057626637895, 1.7579280948318845)
# 2025-10-22 13:08:37,318 INFO sqlalchemy.engine.Engine INSERT INTO "TJCAUSP" ("ORDER_NO", "ORDER_MONTH", "IN_MAT_WIDTH", "IN_MAT_THICK") VALUES (?, ?, ?, ?) RETURNING id
# 2025-10-22 13:08:37,319 INFO sqlalchemy.engine.Engine [insertmanyvalues 100/106 (ordered; batch not supported)] ('G025001340', '202502', 965.5003533824967, 1.763738666249039)
# 2025-10-22 13:08:37,319 INFO sqlalchemy.engine.Engine INSERT INTO "TJCAUSP" ("ORDER_NO", "ORDER_MONTH", "IN_MAT_WIDTH", "IN_MAT_THICK") VALUES (?, ?, ?, ?) RETURNING id
# 2025-10-22 13:08:37,320 INFO sqlalchemy.engine.Engine [insertmanyvalues 101/106 (ordered; batch not supported)] ('G025001340', '202502', 966.9659469190752, 1.7456590125817328)
# 2025-10-22 13:08:37,320 INFO sqlalchemy.engine.Engine INSERT INTO "TJCAUSP" ("ORDER_NO", "ORDER_MONTH", "IN_MAT_WIDTH", "IN_MAT_THICK") VALUES (?, ?, ?, ?) RETURNING id
# 2025-10-22 13:08:37,322 INFO sqlalchemy.engine.Engine [insertmanyvalues 102/106 (ordered; batch not supported)] ('G025001340', '202502', 962.4641779665576, 1.7909398075419904)
# 2025-10-22 13:08:37,322 INFO sqlalchemy.engine.Engine INSERT INTO "TJCAUSP" ("ORDER_NO", "ORDER_MONTH", "IN_MAT_WIDTH", "IN_MAT_THICK") VALUES (?, ?, ?, ?) RETURNING id
# 2025-10-22 13:08:37,322 INFO sqlalchemy.engine.Engine [insertmanyvalues 103/106 (ordered; batch not supported)] ('G025001340', '202502', 962.473862460079, 1.8061190884605651)
# 2025-10-22 13:08:37,323 INFO sqlalchemy.engine.Engine INSERT INTO "TJCAUSP" ("ORDER_NO", "ORDER_MONTH", "IN_MAT_WIDTH", "IN_MAT_THICK") VALUES (?, ?, ?, ?) RETURNING id
# 2025-10-22 13:08:37,324 INFO sqlalchemy.engine.Engine [insertmanyvalues 104/106 (ordered; batch not supported)] ('G025001340', '202502', 963.295694396292, 1.8771060558962192)
# 2025-10-22 13:08:37,324 INFO sqlalchemy.engine.Engine INSERT INTO "TJCAUSP" ("ORDER_NO", "ORDER_MONTH", "IN_MAT_WIDTH", "IN_MAT_THICK") VALUES (?, ?, ?, ?) RETURNING id
# 2025-10-22 13:08:37,325 INFO sqlalchemy.engine.Engine [insertmanyvalues 105/106 (ordered; batch not supported)] ('G025001340', '202502', 961.6075725958377, 1.8258298654474365)
# 2025-10-22 13:08:37,326 INFO sqlalchemy.engine.Engine INSERT INTO "TJCAUSP" ("ORDER_NO", "ORDER_MONTH", "IN_MAT_WIDTH", "IN_MAT_THICK") VALUES (?, ?, ?, ?) RETURNING id
# 2025-10-22 13:08:37,327 INFO sqlalchemy.engine.Engine [insertmanyvalues 106/106 (ordered; batch not supported)] ('G025001340', '202502', 963.6956539356423, 1.8571216668560635)
# 2025-10-22 13:08:37,329 INFO sqlalchemy.engine.Engine COMMIT
# 成功将 106 条记录插入TJCAUSP表中
